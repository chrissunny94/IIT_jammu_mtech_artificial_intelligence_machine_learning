# %% [markdown]
# # Pandas Tutorial

# %%
import pandas as pd

# %%
games = pd.read_csv("vgsalesGlobale.csv", index_col = "Name")

# %%
games.head(5)
# Out:
#                           Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                   1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.            2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii               3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort            4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue     5       GB  1996.0  Role-Playing  Nintendo
#
#                           NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                   41.49     29.02      3.77         8.46
# Super Mario Bros.            29.08      3.58      6.81         0.77
# Mario Kart Wii               15.85     12.88      3.79         3.31
# Wii Sports Resort            15.75     11.01      3.28         2.96
# Pokemon Red/Pokemon Blue     11.27      8.89     10.22         1.00
#
#                           Global_Sales
# Name
# Wii Sports                       82.74
# ...

# %%
games.tail(5)
# Out:
#                                                    Rank Platform    Year  \
# Name
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                      Genre   Publisher  \
# Name
# Woody Woodpecker in Crazy Castle 5                Platform       Kemco
# Men in Black II: Alien Escape                      Shooter  Infogrames
# SCORE International Baja 1000: The Official Game    Racing  Activision
# Know How 2                                          Puzzle    7G//AMES
# Spirits & Spells                                  Platform     Wanadoo
#
#                                                   NA_Sales  EU_Sales  \
# Name
# ...

# %%
len(games)
# Out:
# 16598

# %%
games.shape
# Out:
# (16598, 10)

# %%
games.dtypes
# Out:
# Rank              int64
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
games.iloc[200]
# Out:
# Rank                 201
# Platform              GB
# Year              1999.0
# Genre           Platform
# Publisher       Nintendo
# NA_Sales             3.4
# EU_Sales             1.3
# JP_Sales            0.15
# Other_Sales         0.22
# Global_Sales        5.07
# Name: Super Mario Bros., dtype: object

# %%
games.loc["Super Mario Bros."]
# Out:
#                    Rank Platform    Year     Genre Publisher  NA_Sales  \
# Name
# Super Mario Bros.     2      NES  1985.0  Platform  Nintendo     29.08
# Super Mario Bros.   201       GB  1999.0  Platform  Nintendo      3.40
#
#                    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Super Mario Bros.      3.58      6.81         0.77         40.24
# Super Mario Bros.      1.30      0.15         0.22          5.07

# %%
games.head(10)
# Out:
#                            Rank Platform    Year         Genre Publisher  \
# Name
# Wii Sports                    1      Wii  2006.0        Sports  Nintendo
# Super Mario Bros.             2      NES  1985.0      Platform  Nintendo
# Mario Kart Wii                3      Wii  2008.0        Racing  Nintendo
# Wii Sports Resort             4      Wii  2009.0        Sports  Nintendo
# Pokemon Red/Pokemon Blue      5       GB  1996.0  Role-Playing  Nintendo
# Tetris                        6       GB  1989.0        Puzzle  Nintendo
# New Super Mario Bros.         7       DS  2006.0      Platform  Nintendo
# Wii Play                      8      Wii  2006.0          Misc  Nintendo
# New Super Mario Bros. Wii     9      Wii  2009.0      Platform  Nintendo
# Duck Hunt                    10      NES  1984.0       Shooter  Nintendo
#
#                            NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Name
# Wii Sports                    41.49     29.02      3.77         8.46
# ...

# %%
games.sort_values(by = "Year").head()
# Out:
#           Rank Platform    Year     Genre   Publisher  NA_Sales  EU_Sales  \
# Name
# Checkers  6898     2600  1980.0      Misc       Atari      0.22      0.01
# Boxing    2671     2600  1980.0  Fighting  Activision      0.72      0.04
# Freeway   5368     2600  1980.0    Action  Activision      0.32      0.02
# Defender  1971     2600  1980.0      Misc       Atari      0.99      0.05
# Kaboom!   1768     2600  1980.0      Misc  Activision      1.07      0.07
#
#           JP_Sales  Other_Sales  Global_Sales
# Name
# Checkers       0.0         0.00          0.24
# Boxing         0.0         0.01          0.77
# Freeway        0.0         0.00          0.34
# Defender       0.0         0.01          1.05
# Kaboom!        0.0         0.01          1.15

# %%
games.sort_values(by = "Year", ascending=False).head()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# Shin Megami Tensei IV: Final                       8295      3DS  2016.0
#
#                                                          Genre     Publisher  \
# Name
# Imagine: Makeup Artist                              Simulation       Ubisoft
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing          Sega
# Brothers Conflict: Precious Baby                        Action  Idea Factory
# Shin Megami Tensei IV: Final                      Role-Playing   Deep Silver
#
# ...

# %%
games.sort_values(by = ["Year", "Genre"], ascending=False).head()
# Out:
#                                                    Rank Platform    Year  \
# Name
# Imagine: Makeup Artist                             5959       DS  2020.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  14393      PS4  2017.0
# Phantasy Star Online 2 Episode 4: Deluxe Package  16244      PSV  2017.0
# Brothers Conflict: Precious Baby                  16441      PSV  2017.0
# XCOM 2                                             7566       PC  2016.0
#
#                                                          Genre  \
# Name
# Imagine: Makeup Artist                              Simulation
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Phantasy Star Online 2 Episode 4: Deluxe Package  Role-Playing
# Brothers Conflict: Precious Baby                        Action
# XCOM 2                                                Strategy
#
#                                                              Publisher  \
# Name
# ...

# %%
games.sort_index().head()
# Out:
#                                          Rank Platform    Year         Genre  \
# Name
# '98 Koshien                              4756       PS  1998.0        Sports
# .hack//G.U. Vol.1//Rebirth               8359      PS2  2006.0  Role-Playing
# .hack//G.U. Vol.2//Reminisce             7109      PS2  2006.0  Role-Playing
# .hack//G.U. Vol.2//Reminisce (jp sales)  8604      PS2  2006.0  Role-Playing
# .hack//G.U. Vol.3//Redemption            8306      PS2  2007.0  Role-Playing
#
#                                                   Publisher  NA_Sales  \
# Name
# '98 Koshien                                 Magical Company      0.15
# .hack//G.U. Vol.1//Rebirth               Namco Bandai Games      0.00
# .hack//G.U. Vol.2//Reminisce             Namco Bandai Games      0.11
# .hack//G.U. Vol.2//Reminisce (jp sales)  Namco Bandai Games      0.00
# .hack//G.U. Vol.3//Redemption            Namco Bandai Games      0.00
#
# ...

# %%
games["Publisher"].head(10)
# Out:
# Name
# Wii Sports                   Nintendo
# Super Mario Bros.            Nintendo
# Mario Kart Wii               Nintendo
# Wii Sports Resort            Nintendo
# Pokemon Red/Pokemon Blue     Nintendo
# Tetris                       Nintendo
# New Super Mario Bros.        Nintendo
# Wii Play                     Nintendo
# New Super Mario Bros. Wii    Nintendo
# Duck Hunt                    Nintendo
# Name: Publisher, dtype: object

# %%
games[games["Genre"] =="Sports"]
# Out:
#                                 Rank Platform    Year   Genre  \
# Name
# Wii Sports                         1      Wii  2006.0  Sports
# Wii Sports Resort                  4      Wii  2009.0  Sports
# Wii Fit                           14      Wii  2007.0  Sports
# Wii Fit Plus                      15      Wii  2009.0  Sports
# FIFA 16                           78      PS4  2015.0  Sports
# ...                              ...      ...     ...     ...
# Rugby Challenge 3              16579     XOne  2016.0  Sports
# Outdoors Unleashed: Africa 3D  16581      3DS  2011.0  Sports
# PGA European Tour              16582      N64  2000.0  Sports
# Fit & Fun                      16584      Wii  2011.0  Sports
# Mezase!! Tsuri Master DS       16590       DS  2009.0  Sports
#
#                                           Publisher  NA_Sales  EU_Sales  \
# Name
# Wii Sports                                 Nintendo     41.49     29.02
# ...

# %%
games_by_genre = games["Genre"] =="Action"
games[games_by_genre]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto: San Andreas                          18      PS2  2004.0
# Grand Theft Auto V                                     24     X360  2013.0
# Grand Theft Auto: Vice City                            25      PS2  2002.0
# Grand Theft Auto III                                   39      PS2  2001.0
# ...                                                   ...      ...     ...
# Original Frisbee Disc Sports: Ultimate & Golf       16567       DS  2007.0
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Planet Monsters                                     16585      GBA  2001.0
# Carmageddon 64                                      16586      N64  1999.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
#                                                      Genre  \
# ...

# %%
games_in_2010 = games["Year"] == 2010
games[games_by_genre & games_in_2010]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Red Dead Redemption                                   124      PS3  2010.0
# Red Dead Redemption                                   135     X360  2010.0
# God of War III                                        217      PS3  2010.0
# Assassin's Creed: Brotherhood                         374     X360  2010.0
# Assassin's Creed: Brotherhood                         515      PS3  2010.0
# ...                                                   ...      ...     ...
# Marvel Superheroes 3D: Grandmaster's Challenge      15721      Wii  2010.0
# Metal Fight Beyblade: Choujou Kessen! Big Bang ...  15771       DS  2010.0
# Dark Void                                           15792       PC  2010.0
# Shin Sangoku Musou Online: Souten Ranbu             15871      PS3  2010.0
# Monkey Madness: Island Escape                       16161       DS  2010.0
#
#                                                      Genre  \
# ...

# %%
games[games_by_genre | games_in_2010]
# Out:
#                                                      Rank Platform    Year  \
# Name
# Kinect Adventures!                                     16     X360  2010.0
# Grand Theft Auto V                                     17      PS3  2013.0
# Grand Theft Auto: San Andreas                          18      PS2  2004.0
# Grand Theft Auto V                                     24     X360  2013.0
# Grand Theft Auto: Vice City                            25      PS2  2002.0
# ...                                                   ...      ...     ...
# Fujiko F. Fujio Characters: Great Assembly! Sli...  16570      3DS  2014.0
# Planet Monsters                                     16585      GBA  2001.0
# Carmageddon 64                                      16586      N64  1999.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
# Know How 2                                          16599       DS  2010.0
#
#                                                      Genre  \
# ...

# %%
after_2015 = games["Year"] > 2015
games[after_2015]
# Out:
#                                                      Rank Platform    Year  \
# Name
# FIFA 17                                               222      PS4  2016.0
# Uncharted 4: A Thief's End                            272      PS4  2016.0
# Tom Clancy's The Division                             352      PS4  2016.0
# Far Cry: Primal                                       772      PS4  2016.0
# Tom Clancy's The Division                             847     XOne  2016.0
# ...                                                   ...      ...     ...
# Mighty No. 9                                        16565     XOne  2016.0
# Resident Evil 4 HD                                  16572     XOne  2016.0
# Farming 2017 - The Simulation                       16573      PS4  2016.0
# Rugby Challenge 3                                   16579     XOne  2016.0
# Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirub...  16592      PSV  2016.0
#
# ...

# %%
mid_2000s = games["Year"].between(2000, 2010)
games[mid_2000s]
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# New Super Mario Bros.                                 7       DS  2006.0
# Wii Play                                              8      Wii  2006.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                      Genre   Publisher  \
# Name
# ...

# %%
sport_in_title = games.index.str.lower().str.contains("sport")
games[sport_in_title]
# Out:
#                                                 Rank Platform    Year   Genre  \
# Name
# Wii Sports                                         1      Wii  2006.0  Sports
# Wii Sports Resort                                  4      Wii  2009.0  Sports
# Kinect Sports                                    140     X360  2010.0  Sports
# Forza Motorsport 3                               161     X360  2009.0  Racing
# Forza Motorsport 4                               229     X360  2011.0  Racing
# ...                                              ...      ...     ...     ...
# Disney Sports Football                         15664       GC  2002.0  Sports
# Winter Sports 3: The Great Tournament          15823     X360  2010.0  Sports
# IHRA Drag Racing: Sportsman Edition            15957       XB  2006.0  Racing
# RalliSport Challenge(JP sales)                 16328       XB  2002.0  Racing
# Original Frisbee Disc Sports: Ultimate & Golf  16567       DS  2007.0  Action
#
# ...

# %%
games["Global_Sales"].mean()
# Out:
# 0.5374406555006628

# %%
genres = games.groupby("Genre")

# %%
genres["Global_Sales"].sum()
# Out:
# Genre
# Action          1751.18
# Adventure        239.04
# Fighting         448.91
# Misc             809.96
# Platform         831.37
# Puzzle           244.95
# Racing           732.04
# Role-Playing     927.37
# Shooter         1037.37
# Simulation       392.20
# Sports          1330.93
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
genres["Global_Sales"].sum().sort_values(ascending = False)
# Out:
# Genre
# Action          1751.18
# Sports          1330.93
# Shooter         1037.37
# Role-Playing     927.37
# Platform         831.37
# Misc             809.96
# Racing           732.04
# Fighting         448.91
# Simulation       392.20
# Puzzle           244.95
# Adventure        239.04
# Strategy         175.12
# Name: Global_Sales, dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline

# %%
plt.style.use("fivethirtyeight")

# %%
data = pd.Series(np.random.randn(500).cumsum())

# %%
data.plot()
# Out:
# <Axes: >

# %%
df1 = pd.DataFrame(np.random.randn(100, 4), columns = list('ABCD'))

# %%
df1 = df1.cumsum()

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.iloc[10].plot(kind='bar')
# Out:
# <Axes: >

# %%
df1.iloc[25].plot.bar()
# Out:
# <Axes: >

# %%
df1.iloc[25]
# Out:
# A   -3.365709
# B   -0.085295
# C   -2.995173
# D   -5.217773
# Name: 25, dtype: float64

# %%
df2=pd.DataFrame(np.random.rand(7,3), columns=list("ABC"))

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked  = True)
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked  = True)
# Out:
# <Axes: >

# %%
iris.plot.hist(alpha=0.8)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=0.8, stacked = True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris.plot.hist(alpha=1, stacked = True, bins = 25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
iris
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
iris["sepal.width"].plot.hist(orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["sepal.width"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
iris["sepal.length"].plot.hist(orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["petal.length"].plot.hist(orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris["petal.width"].plot.hist(orientation = "horizontal")
# Out:
# <Axes: xlabel='Frequency'>

# %%
iris.hist(color="blue", alpha=1, bins=20)
# Out:
# array([[<Axes: title={'center': 'sepal.length'}>,
#         <Axes: title={'center': 'sepal.width'}>],
#        [<Axes: title={'center': 'petal.length'}>,
#         <Axes: title={'center': 'petal.width'}>]], dtype=object)

# %%
iris.hist("petal.width",by="variety")
# Out:
# array([[<Axes: title={'center': 'Setosa'}>,
#         <Axes: title={'center': 'Versicolor'}>],
#        [<Axes: title={'center': 'Virginica'}>, <Axes: >]], dtype=object)

# %%
iris.plot.box()
# Out:
# <Axes: >

# %%
colors={'boxes': 'Red', 'whiskers': 'blue','medians': 'Black', 'caps': 'Green'}

# %%
iris.plot.box(color=colors)
# Out:
# <Axes: >

# %%
iris.plot.box(color=colors, vert = False)
# Out:
# <Axes: >
